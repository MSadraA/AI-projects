# %% [markdown]
# # 🤖 AI, CA3, Machine Learning 📚
#
# * **Name** : [Enter your name] 🖊
# * **Last Name** : [Enter your last name] 📝
# * **SID** : [Enter your SID] 🆔

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### 🛠 From Scratch
# In this subsection, you should implement the Decision Tree algorithm 🌳 from scratch 🛠 and compare its performance with the library implementation 📚.

# %%
import numpy as np
import pandas as pd

class MyDecisionTree:
    def __init__(self, max_depth=3):
        """
        max_depth : int
                    Maximum depth of the tree (root has depth 0).
        """
        self.max_depth = max_depth
        # You may add other attributes here

    def fit(self, X, y):
        """
        Build the decision tree from scratch.

        Parameters
        ----------
        X : pd.DataFrame of shape (n_samples, n_features)
            Training features.
        y : pd.Series of shape (n_samples)
            Training labels.
        """
        # TODO: build your tree structure here

    def predict(self, X):
        """
        Predict class labels for samples in X.

        Parameters
        ----------
        X : pd.DataFrame of shape (n_samples, n_features)
            Samples to predict.

        Returns
        ----------
        preds : np.ndarray of shape (n_samples)
                Predicted class labels.
        """
        # TODO: traverse your tree for each sample and return an array of predictions

    # You may need to add any helper methods.

# %%
# Do rest of the sections according to the project description...

# %% [markdown]
# ## Part 2

# %% [markdown]
# ## 🧹 Data Preprocessing
# The preprocessing part is given to you as below.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %%
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    # Lowercase
    text = text.lower()
    # Remove punctuation and special characters (keep only a-z and spaces)
    text = re.sub(r'[^a-z\s]', '', text)
    # Tokenize (split by space)
    words = text.split()
    # Remove stopwords & Lemmatize
    clean_words = [lemmatizer.lemmatize(w) for w in words if w not in stop_words]
    return " ".join(clean_words)

# Apply clean_text() to each email message in your dataframe

# %% [markdown]
# ## Part 3

# %%
# Do the sections according to the project description...

# %% [markdown]
# ## Part 4

# %%
# Do the sections according to the project description...
